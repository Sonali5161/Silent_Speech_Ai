# %%
# %pip install streamlit opencv-python gtts
# Out:
# ...
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# ...
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    ------------- -------------------------- 2.9/8.6 MB 18.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.8/8.6 MB 19.1 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.6 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.6/8.6 MB 14.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/658.1 kB ? eta -:--:--
#    ---------------------------------------- 658.1/658.1 kB 8.4 MB/s eta 0:00:00
# Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# ...
#    ---------------------------------------- 0.0/25.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.2 MB 11.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.4/25.2 MB 12.6 MB/s eta 0:00:02
#    --------- ------------------------------ 6.0/25.2 MB 12.7 MB/s eta 0:00:02
# ...
